# %% [markdown]
# # Pertemuan 12 (21/05/2026)
#
# Kamus :
# - Ortogonal
# - mencari basis dari sebuah komponen
# - untuk mendapatkan basis, setiap vektor dibagi panjang vektor
#
# v = 3,3
# a = 3,3
# u = -3,3
#
# $a=\begin{bmatrix}a_1 \\ a_2\end{bmatrix}$
#
# $b=\begin{bmatrix}b_1 \\ b_2\end{bmatrix}$
#
# maka :
# $|a| = \sqrt{a_1^2 + a_2^2}$
#
# $|b| = \sqrt{b_1^2 + b_2^2}$
#
# $|v| = \sqrt{3^2 + 3^2} = \sqrt{18}$
#
# $|u| = \sqrt{(-3)^2 + 3^2} = \sqrt{9 + 9} = \sqrt{18}$
#
# sehingga :
#
# $u \cdot v = \sqrt{18} \cdot \sqrt{18} Cos 90^{\circ}$
#
# $a \cdot b = |a| \cdot |b| cos 0 -> 0= antara a-b atau a_b$
#
# $a \cdot b = a_1b_1 + a_2b_2$
#
# $uv = -3.3 + 3.3 = -9+9 = 0$
#
# lanjut :
#
# k = 4,3
# E = 4,3 / |k| = (4,3) / $\sqrt{4^2 + 3^2} =$
#
# --bersambung--
