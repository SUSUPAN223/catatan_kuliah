# %% [markdown]
# # Pertemuan 6 07/04/26
#
# Variable :
# - KMeans
# - Clustering
# - k-means clustering dengan k-2
# - misiansasi centroid
#
# UTS ,minggu depan
#
# Materi :
# - algoritma Genetika, Fuzzy, KMeans Clastering
# - 14 4 26 (tanggal)
# - Soal untung pengetahuan, hitung$^2$
#
# Pemrograman : Tugas Fuzzy, Tugas Algoritma Genetika, Tugas KMeans Clustering
#
#
# KMeans adalah pengelompokan datan berdasarkan jarak terdekatnya
#
# Apa itu clustering?
# Clustering adalah pengelompokan berdasarkan kriteria, misal pengelonpokan kriteria kemiripan tabung, warna
#
# TUGAS K-Means:
# - Membuat perhitungan manual untuk K-Meang clustering
# - datanya bebas mau x dan y, jadi ambil sejumlah data x, 2 fitur saja minimal 20
# - cari k nya berapa, gunakan elbow method
# - misal sudah tau k nya berapa, lalu lakukan perhitungan manual berdasarkan k yang sudah ketemu itu
# - data centroid nya bebas mau yang terjauh atau terdekat
# - codenya menggunakan library fungsi python
# - data orange, nama appsnya orange data
# - ambil data yang sama, k yang sama
# - program sendiri dari perhitungan manual
# kelompok 4 orang dengan waktu 2 minggu
