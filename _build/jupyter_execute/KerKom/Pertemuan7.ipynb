# %% [markdown]
# # Pertemuan 7(21/04/26)
#
# Isi dari Teacheble Machine adalah deep learning
#
# Ketika kamu membuat sebuah program machine learning, saat ada di tahap test, gunakan data yang berbeda, agar kamu tau program sudah berjalan dengan benar atau tidak
#
# Tahapannya:
#
# Augmentasi
# Data Trining + Data Validasi
#
# Data Testing
