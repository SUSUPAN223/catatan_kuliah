# %% [markdown]
# PERTEMUAN 4

# %% [markdown]
# *IDENTIFIKASI OUTLIER*
# Saat kita mengidentifikasi outlier, hal yang paling efektif yang dapat kita lakukan adalah dengan melakukan penggabungan beberapa metode deteksi outlier, untuk menaikkan tingkat akurasi metode yang kita miliki dalam menentukan outlier
#
#
# *MISSING VALUES*
# Setelah melakukan pendeteksian outlier, sekarang kita tentukan Missing  Value nya, salah satu metode yang dapat digunakan adalah Linear Interpolation, jika memungkinkan gunakan pernggabungan metode
#
# TUGAS :
#
# BUAT DIMENSINYA MENJADI 20 di PCA
#
# Dari excel reader langsung ke K-means datanya 272
#
# kita akan bandingkan apakah dengan PCA atau tanpa PCA itu sama atau tidak
#
# untuk menggunakan PCA, dijadikan 2 cluster lalu bisa cluster a 4 orang, cluster b 16 orang kemudian di olah di PCA sebanyak 20 dimensi
#
# untuk yang tanpa PCA gunakan siapa dan siapa
