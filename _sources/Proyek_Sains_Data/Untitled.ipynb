# %% [markdown]
# # Pertemuan 2

# %% [markdown]
# ## Data Understanding
#
# Kata Kunci yang perlu dipahami :
# - Type Data
# - Skewed data
#
#
# Type data:
# *data terstrukur dan data tidak terstruktur.*
#
# dimana tipe data ada macam macam, bisa dalam bentuk numeric, dll.
#
# *Graphs dan networks*
#
# adalah keterhubungan atau keterikatan suatu data ke data yang lain
#
# *Ordered Data*
#
# Urutan data yang diambil dari sebuah video kemudian dipecah menjadi gambar gambar.
#
# *Spatial, image and multimedia data*
#
# Data yang menunjukkan hubungan antara lokasi dan juga ruang
#
#
# *Karakteristik  Struktur Data*
#
# - Dimensionality
# - Sparsity
# - Resolution
# - Distribution
#
# Kolom = fitur, dimensi
# Baris : Data object
#
#
# Atribut
#
# Type :
# - Nominal, contoh nama, nim, agama, warna (data yang sifatnya umum tanpa peringkat)
# - Binary (Data dengan dua kategori atau status) -> symmetric binary and Asymmetric binary
# - Ordinal (Data yang memiliki tingkatan)
# - Numeric quantitative -> Interval-scaled, Ratio-Scaled
# - Discrete vs continues
#
# Statics of data
#
# Basic Statistical of data
#
# - Motivation
# - Data dispersion characteristics
# - Numerical dimensions correspond
#
# Measuring the central tendecy
#
# - Mean
# - Median
# - Modus
#
#
# cara membaca skewed data apakah positif atau negatif adalah dengan memberhatikan mana yang ke tempat rendah, jika yang ketempat rendah setelahnya dan dimulainya dari modus median mean, maka itu adalah positif
# sedangkah jika dia dari tempat rendah dulu lalu ke mean median modus, berarti itu adalah negatif
#
#
#
# cara mencari variasi :
#
# setiap data dikurangi rata rata lalu di kuadratkan
# lalu hasil kuadrat dimasukkan ke rumus sigma dimana hasil kuadrat dibagi total keseluruhan data dikurangi 1
#
#
# jika mencari kovariance atau 2 baris (bukan 1) maka caranya berbeda
#
# untuk mencari korelasi adalah dengan membagi kovarian dengan standar deviasi 1 dan standar deviasi 2
