# %% [markdown]
# # Pertemuan 8 (28/04/26)
#
# Kamus :
# - Learning Rate adalah kecepatan pembelajaran
#
#
# Jika Outputnya adalah 0 sedangkan harapannya adalah 1 maka bobotnya harus di update, dari x11,x21, x31 ke x12, x22, x,32
#
# jika Output yang ditargetkan adalah 0 sedangkan outputnya adalah 1, maka bobot dikurangi
#
# Bobotnya Bias itu kita yang menentukan
#
# uang 600k nabung 200?
#
# Tugas:
# - Buat program logika and dan logika or
# - pakai step function
# - epo harus mencakup ke semua data, misal di epo ke 12 sudah ketemu 0, lalu datanya ada 15 maka harus dilanjutkan sampai ke data 15
# - jadi tampilkan berupa table
#
# contoh :
# pembelajaran 1
#
# w0
#
# w1
#
# w2
#
# epoch
#
# pembelajaran 2 : 0.1
#
# w0
#
# w1
#
# w2
#
# epoch
#
# pembelajaran 2 :0.01
#
# w0
#
# w1
#
# w2
#
# epoch
#
#
# pembelajaran 2 : 0.001
#
# w0
#
# w1
#
# w2
#
# epoch
