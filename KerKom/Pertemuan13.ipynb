# %% [markdown]
# # Pertemuan 13 (02/06/2026)
#
# kamus :
# - pheromone
# - ant koloni seperti semut
#
#
# semut akan berjalan menyesuaikan feromon, semakin banyak feromon, maka jalur itu akan menjadi rute
#
# implementasi di TSP itu yang jalur terpendek itu yang ada feromonnya,
#
# nnn
