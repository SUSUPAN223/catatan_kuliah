# %% [markdown]
# # Pertemuan 9(30/04/2026)
#
# kosa kata :
# - Verifikasi Transformasi Linier
# - Perkalian Skalar
#
# Transformaso Matrix
#
# Dalam proses klasifikasi jika sebuah data tidak bisa di pisahkan dalam bentuk suatu dimensi, berarti kita butuh menggunakan dimensi yang lebih tinggi.
#
# suatu fungsi dari cara melakukan cerminan adalah seperti ini:
#
# $R^2 -> R^2$  $v=(v_1 , v_2) ER^2$
#
# $T(v_1 , v_2) = (v_1 - v_2 , v_1 + 2v_2)$
#
# Transformasi Linier
#
# v,w Ruang Vektor
#
# T V -> W maka V ke W transformasi linier
#
# $(1) T(u+v) = T(u) + T(v), A(kebalik)U, V E V(V miring)$
#
# $(2) T(cu) = cT(u)  Ac E R$
