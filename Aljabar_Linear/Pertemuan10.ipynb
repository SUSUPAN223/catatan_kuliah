# %% [markdown]
# # Pertemuan 10 (07/05/2026)
#
# Kamus :
#
# - Contractions & Expansions
# - horizontal contractions & expansions
# - vertical ~~~~~"~~~~~"~~~~~~"~~~~~"~~
# - Matriks Transformasi Gabungan
#
#
# Materi :
# A = 4,3, B = 4,4, C = 6,4, D = 6,3
#
# Kemudian menggunakan cerminan di y = 2, maka A menjadi 4,1, B menjadi 4,0, C menjadi 6,0 dan D menjadi 6,1
#
# Berapa nilai matriks, atau matriks transformasinya saat ini
#
# Maka digunakan rumus 4a+3b=4, 4c+3d=1 pada titik A, kemudian 4a+4b=4, 4c+4d=0 untuk titik B,
#
# Jawab :
#
# ambil 2 titik dengan nilai x yang sama A dan B dulu
#
# A=4,3 B=4,4
#
# maka ditemukan persamaan 4a+3b=4, 4c+3d=1 dan 4a+4b=4, 4c+4d=0
#
#
#
# Question :
#
# - Bagaimana cara menentukan sebuah matriks transformasi jika tidak diberika rumus dasar seperti $v_1 + v_2, v_1 + 2v_2$ ?
#
# Rumus :
#
# $\begin{matrix}1&0\\0&-1\end{matrix}$ x $\begin{matrix}6\\3\end{matrix}$ + $\begin{matrix}0\\2.2\end{matrix}$
#
# note: jika y atau titik pencerminannya di y = 3 maka 2.3 bukan 2.2 lagi
#
# maka :
#
# $\begin{matrix}6\\3\end{matrix}$ + $\begin{matrix}0\\4\end{matrix}$ = $\begin{matrix}6\\1\end{matrix}$
#
#
# jika meregang kesamping maka $\begin{matrix}k&0\\0&1\end{matrix}$
#
# jika meregang ke atas maka $\begin{matrix}1&0\\0&k\end{matrix}$
#
# jika akan melakukan keduanya maka k berada pada keduanya
#
# jika meregang ke samping namun miring (shears) maka : $\begin{matrix}1&k\\0&1\end{matrix}$
#
# jika meregang secara vertical namun miring (shears) maka : $\begin{matrix}1&0\\k&1\end{matrix}$
#
# Jika dilakukan matrix transformasi gabungan dengan cara memperbesar matris lalu memiringkan secara horizontal kemudian memiringkan lagi secara vertical, maka hasilnya adalah $\begin{matrix}k&k^2\\k^2&k^3+k\end{matrix}$
#
#
# Bikin program abcd dipindah ke ijkl setelah berpindah ke ijkl,
